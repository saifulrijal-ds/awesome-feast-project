# %%
import pandas as pd
from datetime import datetime
from feast import FeatureStore

# %%
# Initialize the feature store with your local configuration
# store = FeatureStore(
#     repo_path="../feature_repo_local",
# )

# %%
# Initialize the feature store with your remote configuration
store = FeatureStore(
    repo_path="../feature_repo_local",
)

# %%
entity_df = pd.read_csv("../feature_repo/data/bfi_static_loan_data.csv")
entity_df['event_timestamp'] = pd.to_datetime(entity_df['event_timestamp'])

start_date = '2023-01-01'
end_date = '2023-10-01'
entity_df = entity_df.query('event_timestamp >= @start_date and event_timestamp < @end_date')[['loan_id', 'customer_id', 'event_timestamp']]

entity_df.head()
# Out:
#   loan_id customer_id event_timestamp
# 0  L10001       C2824      2023-01-18
# 1  L10002       C1409      2023-05-26
# 3  L10004       C5012      2023-01-09
# 4  L10005       C4657      2023-09-23
# 5  L10006       C3286      2023-03-11

# %%
# SQL query that directly selects loan_id and timestamps within your desired date range
# This approach lets you select exactly the entities and timeframe you want
# sql_query = """
#     SELECT
#         loan_id, -- Define all enity
#         customer_id, -- Define all entity
#         event_timestamp 
#     FROM 
#         bfi_static_loan_data 
#     WHERE 
#         event_timestamp BETWEEN '2023-01-01' AND '2023-10-01'
# """



# Retrieve all features from the updated static_loan_features view
# Note that we're now including the new fields we added
training_df = store.get_historical_features(
    entity_df=entity_df,
    features=[
        # Original features
        "static_loan_features:loan_amount",
        "static_loan_features:interest_rate",
        "static_loan_features:loan_term",
        "static_loan_features:product_type",
        "static_loan_features:collateral_value",
        "static_loan_features:ltv_ratio",
        "static_loan_features:credit_score",
        "static_loan_features:monthly_income",
        "static_loan_features:dti_ratio",
        "static_loan_features:age",
        "static_loan_features:employment_years",
        "static_loan_features:province",
        "static_loan_features:urban_rural",
        
        # Newly added features
        "static_loan_features:origination_date",
        "static_loan_features:time_to_event",
        "static_loan_features:default_flag",
        "static_loan_features:observed"
    ],
).to_df()

# Display information about the retrieved data
print(f"Retrieved {len(training_df)} rows of historical feature data")
print(f"Features included: {training_df.columns.tolist()}")
print(f"Date range: {training_df['event_timestamp'].min()} to {training_df['event_timestamp'].max()}")

# Basic data exploration with the new fields
print("\nSummary statistics for key features:")
summary_stats = training_df[['loan_amount', 'interest_rate', 'ltv_ratio', 'time_to_event']].describe()
print(summary_stats)

# Check default distribution
default_count = training_df['default_flag'].sum()
print(f"\nDefault rate: {default_count}/{len(training_df)} ({default_count/len(training_df)*100:.2f}%)")

# Observed vs unobserved events
observed_count = training_df['observed'].sum()
print(f"Observed events: {observed_count}/{len(training_df)} ({observed_count/len(training_df)*100:.2f}%)")

# Analyzing time to event distribution by default status
print("\nTime to event statistics by default status:")
print(training_df.groupby('default_flag')['time_to_event'].describe())

# Save the complete dataset for model training
training_df.to_csv("bfi_loan_complete_training_data.csv", index=False)
print("\nComplete training data saved to bfi_loan_complete_training_data.csv")
# Out:
# Retrieved 3702 rows of historical feature data
# Features included: ['loan_id', 'customer_id', 'event_timestamp', 'loan_amount', 'interest_rate', 'loan_term', 'product_type', 'collateral_value', 'ltv_ratio', 'credit_score', 'monthly_income', 'dti_ratio', 'age', 'employment_years', 'province', 'urban_rural', 'origination_date', 'time_to_event', 'default_flag', 'observed']
# Date range: 2023-01-01 00:00:00 to 2023-09-30 00:00:00
#
# Summary statistics for key features:
#         loan_amount  interest_rate    ltv_ratio  time_to_event
# count  3.702000e+03    3702.000000  3702.000000    3702.000000
# mean   5.540440e+07      17.071556     0.988971      15.048082
# std    5.774547e+07       2.588608     0.127315       8.653020
# min    4.973699e+06      12.000000     0.770000       1.000000
# 25%    1.387325e+07      15.300000     0.900000       8.000000
# 50%    1.963320e+07      16.900000     0.970000      12.000000
# 75%    9.360733e+07      19.000000     1.090000      24.000000
# max    4.180482e+08      22.000000     1.250000      48.000000
#
# Default rate: 2050/3702 (55.38%)
# Observed events: 2050/3702 (55.38%)
#
# Time to event statistics by default status:
#                count       mean       std   min   25%   50%   75%   max
# default_flag
# 0             1652.0  21.552058  4.837049  12.0  24.0  24.0  24.0  24.0
# 1             2050.0   9.806829  7.402712   1.0   4.0   9.0  12.0  48.0
#
# Complete training data saved to bfi_loan_complete_training_data.csv

# %%
training_df
# Out:
#      loan_id customer_id event_timestamp  loan_amount  interest_rate  \
# 0     L10001       C2824      2023-01-18    132049269           16.4
# 1     L10002       C1409      2023-05-26    102430418           12.9
# 2     L10004       C5012      2023-01-09    147151597           17.0
# 3     L10005       C4657      2023-09-23     89938163           13.8
# 4     L10006       C3286      2023-03-11     12740304           18.0
# ...      ...         ...             ...          ...            ...
# 3697  L14995       C5162      2023-01-02    131933556           16.5
# 3698  L14996       C6898      2023-08-22     68874172           15.9
# 3699  L14998       C8331      2023-07-25     63903206           12.0
# 3700  L14999       C7505      2023-03-13     18779891           17.4
# 3701  L15000       C1003      2023-01-14     18869644           17.5
#
#       loan_term product_type  collateral_value  ltv_ratio  credit_score  \
# 0            24          Car         155764993       0.85           628
# 1            60          Car         107223993       0.96           711
# 2            24          Car         156525409       0.94           684
# 3            60          Car         104096852       0.86           725
# 4            12   Motorcycle          11305347       1.13           700
# ...         ...          ...               ...        ...           ...
# 3697         36          Car         168648590       0.78           678
# 3698         36          Car          88922626       0.77           732
# 3699         12          Car          77931980       0.82           631
# 3700         36   Motorcycle          17966475       1.05           709
# 3701         12   Motorcycle          15186496       1.24           705
#
#       monthly_income  dti_ratio  age  employment_years   province urban_rural  \
# 0           18047162       0.52   36               3.4       Bali       Urban
# 1           17370151       0.32   37               3.3    Jakarta       Urban
# 2           16062879       0.46   41               6.5  West Java       Urban
# 3           16763699       0.19   38               1.8  West Java       Urban
# 4            7914012       0.15   42               2.0     Banten       Urban
# ...              ...        ...  ...               ...        ...         ...
# 3697         8888394       0.57   47               3.3    Jakarta       Urban
# 3698        17800133       0.32   43               4.7     Banten       Urban
# 3699        13863629       0.54   35               3.2  East Java       Urban
# 3700         3520890       0.26   21              10.5  East Java       Urban
# 3701         3678083       0.63   47               4.2    Jakarta       Rural
#
#      origination_date  time_to_event  default_flag  observed
# 0          2023-01-18             12             1         1
# 1          2023-05-26             24             0         0
# 2          2023-01-09             24             0         0
# 3          2023-09-23             24             0         0
# 4          2023-03-11             12             1         1
# ...               ...            ...           ...       ...
# 3697       2023-01-02              1             1         1
# 3698       2023-08-22             24             0         0
# 3699       2023-07-25              7             1         1
# 3700       2023-03-13             24             0         0
# 3701       2023-01-14              3             1         1
#
# [3702 rows x 20 columns]

# %% [markdown]
# ### Get historical data using feature service

# %%
feature_refs = store.get_feature_service("combined_prediction_service")


combined_df = store.get_historical_features(
    entity_df=entity_df,
    features=feature_refs
).to_df()

# %%
combined_df.head()
# Out:
#   loan_id customer_id event_timestamp payment_status  days_past_due  \
# 0  L10001       C2824      2023-01-18           None            NaN
# 1  L10002       C1409      2023-05-26           None            NaN
# 2  L10004       C5012      2023-01-09           None            NaN
# 3  L10005       C4657      2023-09-23           None            NaN
# 4  L10006       C3286      2023-03-11           None            NaN
#
#    remaining_balance  payment_amount  inflation_rate  unemployment_rate  \
# 0                NaN             NaN             NaN                NaN
# 1                NaN             NaN             NaN                NaN
# 2                NaN             NaN             NaN                NaN
# 3                NaN             NaN             NaN                NaN
# 4                NaN             NaN             NaN                NaN
#
#    exchange_rate  loan_amount  interest_rate  loan_term product_type  \
# 0            NaN    132049269           16.4         24          Car
# 1            NaN    102430418           12.9         60          Car
# 2            NaN    147151597           17.0         24          Car
# 3            NaN     89938163           13.8         60          Car
# 4            NaN     12740304           18.0         12   Motorcycle
#
#    ltv_ratio  credit_score  dti_ratio  monthly_income
# 0       0.85           628       0.52        18047162
# 1       0.96           711       0.32        17370151
# 2       0.94           684       0.46        16062879
# 3       0.86           725       0.19        16763699
# 4       1.13           700       0.15         7914012

# %% [markdown]
# - [x] Failed
# 1. Disamakan ttl (asumsi data yang melewati ttl tidak akan dikembalikan/dimunculkan) [x] Failed
# 2. Sama sama menggunakan 1 entity [x] Failed

# %% [markdown]
# ### Push

# %%
training_df.columns
# Out:
# Index(['loan_id', 'customer_id', 'event_timestamp', 'loan_amount',
#        'interest_rate', 'loan_term', 'product_type', 'collateral_value',
#        'ltv_ratio', 'credit_score', 'monthly_income', 'dti_ratio', 'age',
#        'employment_years', 'province', 'urban_rural', 'origination_date',
#        'time_to_event', 'default_flag', 'observed'],
#       dtype='object')

# %%
dropped_columns = ['monthly_income', 'age', 'employment_years', 'province', 'urban_rural', 'observed']
pushed_training_df = training_df.drop(columns=dropped_columns)

# %%
pushed_training_df
# Out:
#      loan_id customer_id event_timestamp  loan_amount  interest_rate  \
# 0     L10001       C2824      2023-01-18    132049269           16.4
# 1     L10002       C1409      2023-05-26    102430418           12.9
# 2     L10004       C5012      2023-01-09    147151597           17.0
# 3     L10005       C4657      2023-09-23     89938163           13.8
# 4     L10006       C3286      2023-03-11     12740304           18.0
# ...      ...         ...             ...          ...            ...
# 3697  L14995       C5162      2023-01-02    131933556           16.5
# 3698  L14996       C6898      2023-08-22     68874172           15.9
# 3699  L14998       C8331      2023-07-25     63903206           12.0
# 3700  L14999       C7505      2023-03-13     18779891           17.4
# 3701  L15000       C1003      2023-01-14     18869644           17.5
#
#       loan_term product_type  collateral_value  ltv_ratio  credit_score  \
# 0            24          Car         155764993       0.85           628
# 1            60          Car         107223993       0.96           711
# 2            24          Car         156525409       0.94           684
# 3            60          Car         104096852       0.86           725
# 4            12   Motorcycle          11305347       1.13           700
# ...         ...          ...               ...        ...           ...
# 3697         36          Car         168648590       0.78           678
# 3698         36          Car          88922626       0.77           732
# 3699         12          Car          77931980       0.82           631
# 3700         36   Motorcycle          17966475       1.05           709
# 3701         12   Motorcycle          15186496       1.24           705
#
#       dti_ratio origination_date  time_to_event  default_flag
# 0          0.52       2023-01-18             12             1
# 1          0.32       2023-05-26             24             0
# 2          0.46       2023-01-09             24             0
# 3          0.19       2023-09-23             24             0
# 4          0.15       2023-03-11             12             1
# ...         ...              ...            ...           ...
# 3697       0.57       2023-01-02              1             1
# 3698       0.32       2023-08-22             24             0
# 3699       0.54       2023-07-25              7             1
# 3700       0.26       2023-03-13             24             0
# 3701       0.63       2023-01-14              3             1
#
# [3702 rows x 14 columns]

# %%
store.push("statical_loan_push_source", pushed_training_df)
# Out:
# ---------------------------------------------------------------------------
# PushSourceNotFoundException               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 store.push("statical_loan_push_source", pushed_training_df)
#
# File ~/.local/share/virtualenvs/feast-exercises-tcmK_nBw/lib/python3.11/site-packages/feast/feature_store.py:1477, in FeatureStore.push(self, push_source_name, df, allow_registry_cache, to, transform_on_write)
#    1459 def push(
#    1460     self,
#    1461     push_source_name: str,
#    (...)   1465     transform_on_write: bool = True,
#    1466 ):
#    1467     """
#    1468     Push features to a push source. This updates all the feature views that have the push source as stream source.
#    1469
#    (...)   1475         transform_on_write: Whether to transform the data before pushing.
#    1476     """
# -> 1477     for fv in self._fvs_for_push_source_or_raise(
#    1478         push_source_name, allow_registry_cache
#    1479     ):
#    1480         if to == PushMode.ONLINE or to == PushMode.ONLINE_AND_OFFLINE:
#    1481             self.write_to_online_store(
#    1482                 fv.name,
#    1483                 df,
#    1484                 allow_registry_cache=allow_registry_cache,
#    1485                 transform_on_write=transform_on_write,
#    1486             )
#
# File ~/.local/share/virtualenvs/feast-exercises-tcmK_nBw/lib/python3.11/site-packages/feast/feature_store.py:1455, in FeatureStore._fvs_for_push_source_or_raise(self, push_source_name, allow_cache)
#    1444 fvs_with_push_sources = {
#    1445     fv
#    1446     for fv in all_fvs
#    (...)   1451     )
#    1452 }
#    1454 if not fvs_with_push_sources:
# -> 1455     raise PushSourceNotFoundException(push_source_name)
#    1457 return fvs_with_push_sources
#
# PushSourceNotFoundException: Unable to find push source 'statical_loan_push_source'.

# %%
print(store.list_data_sources())      # should include statical_loan_push_source
# print(store.list_push_sources())      # should include statical_loan_push_source
print("---")
print(store.list_feature_views())
# Out:
# [<feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457bd01910>, <feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457bd10890>, <feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457bd13c50>, <feast.data_source.PushSource object at 0x70457be37f90>, <feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457be377d0>]
# ---
# [<FeatureView(name = static_loan_features, entities = ['loan'], ttl = 3650 days, 0:00:00, stream_source = None, batch_source = {
#   "type": "CUSTOM_SOURCE",
#   "timestampField": "event_timestamp",
#   "customOptions": {
#     "configuration": "..."
#   },
#   "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#   "name": "static_loan_source"
# }, entity_columns = [Field(
#     name='loan_id',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], features = [Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='collateral_value',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='monthly_income',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='age',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='employment_years',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='province',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='urban_rural',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='origination_date',
#     dtype=<PrimitiveFeastType.UNIX_TIMESTAMP: 8>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='time_to_event',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='default_flag',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='observed',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], description = , tags = {'category': 'loan_origination', 'owner': 'credit_team'}, owner = , projection = FeatureViewProjection(name='static_loan_features', name_alias=None, desired_features=[], features=[Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='collateral_value',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='monthly_income',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='age',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='employment_years',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='province',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='urban_rural',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='origination_date',
#     dtype=<PrimitiveFeastType.UNIX_TIMESTAMP: 8>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='time_to_event',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='default_flag',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='observed',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], join_key_map={}, timestamp_field=None, date_partition_column=None, created_timestamp_column=None, batch_source=<feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457be34310>), created_timestamp = 2025-05-16 14:31:45.252427, last_updated_timestamp = 2025-05-16 16:42:21.701215, source = {
#   "type": "CUSTOM_SOURCE",
#   "timestampField": "event_timestamp",
#   "customOptions": {
#     "configuration": "..."
#   },
#   "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#   "name": "static_loan_source"
# }, online = True, offline = False, materialization_intervals = [])>, <FeatureView(name = time_varying_features, entities = ['loan'], ttl = 3650 days, 0:00:00, stream_source = None, batch_source = {
#   "type": "CUSTOM_SOURCE",
#   "timestampField": "event_timestamp",
#   "customOptions": {
#     "configuration": "..."
#   },
#   "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#   "name": "time_varying_source"
# }, entity_columns = [Field(
#     name='loan_id',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], features = [Field(
#     name='payment_status',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='days_past_due',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='remaining_balance',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='payment_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='inflation_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='unemployment_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='exchange_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], description = , tags = {'category': 'payment_behavior', 'owner': 'collections_team'}, owner = , projection = FeatureViewProjection(name='time_varying_features', name_alias=None, desired_features=[], features=[Field(
#     name='payment_status',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='days_past_due',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='remaining_balance',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='payment_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='inflation_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='unemployment_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='exchange_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], join_key_map={}, timestamp_field=None, date_partition_column=None, created_timestamp_column=None, batch_source=<feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457bd5fa50>), created_timestamp = 2025-05-16 14:31:45.271744, last_updated_timestamp = 2025-05-16 16:42:21.666042, source = {
#   "type": "CUSTOM_SOURCE",
#   "timestampField": "event_timestamp",
#   "customOptions": {
#     "configuration": "..."
#   },
#   "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#   "name": "time_varying_source"
# }, online = True, offline = False, materialization_intervals = [])>, <FeatureView(name = push_loan_features, entities = ['loan'], ttl = 3650 days, 0:00:00, stream_source = {
#   "type": "PUSH_SOURCE",
#   "name": "statical_loan_push_source",
#   "batchSource": {
#     "type": "CUSTOM_SOURCE",
#     "timestampField": "event_timestamp",
#     "createdTimestampColumn": "created",
#     "customOptions": {
#       "configuration": "..."
#     },
#     "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#     "name": "statical_loan_batch_source"
#   }
# }, batch_source = {
#   "type": "CUSTOM_SOURCE",
#   "timestampField": "event_timestamp",
#   "createdTimestampColumn": "created",
#   "customOptions": {
#     "configuration": "..."
#   },
#   "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#   "name": "statical_loan_batch_source"
# }, entity_columns = [Field(
#     name='loan_id',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], features = [Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='collateral_value',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='origination_date',
#     dtype=<PrimitiveFeastType.UNIX_TIMESTAMP: 8>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='time_to_event',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='default_flag',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], description = , tags = {'category': 'push_loan_origination', 'owner': 'data_engineer_team'}, owner = , projection = FeatureViewProjection(name='push_loan_features', name_alias=None, desired_features=[], features=[Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='collateral_value',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='origination_date',
#     dtype=<PrimitiveFeastType.UNIX_TIMESTAMP: 8>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='time_to_event',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='default_flag',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], join_key_map={}, timestamp_field='created', date_partition_column=None, created_timestamp_column='created', batch_source=<feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457bd5da10>), created_timestamp = 2025-05-16 16:13:17.475812, last_updated_timestamp = 2025-05-16 16:42:21.683477, source = {
#   "type": "CUSTOM_SOURCE",
#   "timestampField": "event_timestamp",
#   "createdTimestampColumn": "created",
#   "customOptions": {
#     "configuration": "..."
#   },
#   "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#   "name": "statical_loan_batch_source"
# }, online = True, offline = False, materialization_intervals = [])>, <FeatureView(name = combined_loan_features, entities = ['loan', 'customer'], ttl = 3650 days, 0:00:00, stream_source = None, batch_source = {
#   "type": "CUSTOM_SOURCE",
#   "timestampField": "event_timestamp",
#   "customOptions": {
#     "configuration": "..."
#   },
#   "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#   "name": "combined_loan_source"
# }, entity_columns = [Field(
#     name='loan_id',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='customer_id',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], features = [Field(
#     name='payment_status',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='days_past_due',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='remaining_balance',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='payment_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='inflation_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='unemployment_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='exchange_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='monthly_income',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='province',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='urban_rural',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], description = , tags = {'category': 'combined_view', 'owner': 'data_science_team'}, owner = , projection = FeatureViewProjection(name='combined_loan_features', name_alias=None, desired_features=[], features=[Field(
#     name='payment_status',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='days_past_due',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='remaining_balance',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='payment_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='inflation_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='unemployment_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='exchange_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='monthly_income',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='province',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='urban_rural',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], join_key_map={}, timestamp_field=None, date_partition_column=None, created_timestamp_column=None, batch_source=<feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457bd5f250>), created_timestamp = 2025-05-16 14:31:45.289011, last_updated_timestamp = 2025-05-16 16:42:21.644821, source = {
#   "type": "CUSTOM_SOURCE",
#   "timestampField": "event_timestamp",
#   "customOptions": {
#     "configuration": "..."
#   },
#   "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#   "name": "combined_loan_source"
# }, online = True, offline = False, materialization_intervals = [])>]

# %%
fv = store.list_feature_views()[0]

# %%
fv
# Out:
# <FeatureView(name = static_loan_features, entities = ['loan'], ttl = 3650 days, 0:00:00, stream_source = None, batch_source = {
#   "type": "CUSTOM_SOURCE",
#   "timestampField": "event_timestamp",
#   "customOptions": {
#     "configuration": "..."
#   },
#   "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#   "name": "static_loan_source"
# }, entity_columns = [Field(
#     name='loan_id',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], features = [Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='collateral_value',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='monthly_income',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='age',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='employment_years',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='province',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='urban_rural',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='origination_date',
#     dtype=<PrimitiveFeastType.UNIX_TIMESTAMP: 8>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='time_to_event',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='default_flag',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='observed',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], description = , tags = {'category': 'loan_origination', 'owner': 'credit_team'}, owner = , projection = FeatureViewProjection(name='static_loan_features', name_alias=None, desired_features=[], features=[Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='collateral_value',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='monthly_income',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='age',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='employment_years',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='province',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='urban_rural',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='origination_date',
#     dtype=<PrimitiveFeastType.UNIX_TIMESTAMP: 8>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='time_to_event',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='default_flag',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='observed',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], join_key_map={}, timestamp_field=None, date_partition_column=None, created_timestamp_column=None, batch_source=<feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x704582f1cd50>), created_timestamp = 2025-05-16 14:31:45.252427, last_updated_timestamp = 2025-05-16 16:42:21.701215, source = {
#   "type": "CUSTOM_SOURCE",
#   "timestampField": "event_timestamp",
#   "customOptions": {
#     "configuration": "..."
#   },
#   "dataSourceClassType": "feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource",
#   "name": "static_loan_source"
# }, online = True, offline = False, materialization_intervals = [])>

# %%
print(store.list_feature_services())
# Out:
# [<FeatureService(name = loan_prediction_service, _features = [], feature_view_projections = [FeatureViewProjection(name='static_loan_features', name_alias=None, desired_features=[], features=[Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='collateral_value',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='monthly_income',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='age',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='employment_years',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='province',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='urban_rural',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], join_key_map={}, timestamp_field=None, date_partition_column=None, created_timestamp_column=None, batch_source=<feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457be70490>)], description = , tags = {'description': 'Features for loan prediction models'}, owner = , created_timestamp = 2025-05-16 14:31:45.386413, last_updated_timestamp = 2025-05-16 16:42:21.778828, logging_config = None)>, <FeatureService(name = combined_prediction_service, _features = [], feature_view_projections = [FeatureViewProjection(name='time_varying_features', name_alias=None, desired_features=[], features=[Field(
#     name='payment_status',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='days_past_due',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='remaining_balance',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='payment_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='inflation_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='unemployment_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='exchange_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], join_key_map={}, timestamp_field=None, date_partition_column=None, created_timestamp_column=None, batch_source=<feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457be72ed0>), FeatureViewProjection(name='static_loan_features', name_alias=None, desired_features=[], features=[Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='monthly_income',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], join_key_map={}, timestamp_field=None, date_partition_column=None, created_timestamp_column=None, batch_source=<feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x70457be71a90>)], description = , tags = {'description': 'Combined time-varying and static features for enhanced prediction'}, owner = , created_timestamp = 2025-05-16 14:31:45.369636, last_updated_timestamp = 2025-05-16 16:42:21.795194, logging_config = None)>]

# %%
feature_refs = store.get_feature_service("loan_prediction_service")

# %%
feature_refs
# Out:
# <FeatureService(name = loan_prediction_service, _features = [], feature_view_projections = [FeatureViewProjection(name='static_loan_features', name_alias=None, desired_features=[], features=[Field(
#     name='loan_amount',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='interest_rate',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='loan_term',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='product_type',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='collateral_value',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='ltv_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='credit_score',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='monthly_income',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='dti_ratio',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='age',
#     dtype=<PrimitiveFeastType.INT64: 4>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='employment_years',
#     dtype=<PrimitiveFeastType.FLOAT32: 6>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='province',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# ), Field(
#     name='urban_rural',
#     dtype=<PrimitiveFeastType.STRING: 2>,
#     description='',
#     tags={}
#     vector_index=False
#     vector_length=0
#     vector_search_metric=''
# )], join_key_map={}, timestamp_field=None, date_partition_column=None, created_timestamp_column=None, batch_source=<feast.infra.offline_stores.contrib.postgres_offline_store.postgres_source.PostgreSQLSource object at 0x710da7b2b750>)], description = , tags = {'description': 'Features for loan prediction models'}, owner = , created_timestamp = 2025-05-16 14:31:45.386413, last_updated_timestamp = 2025-05-16 16:42:21.778828, logging_config = None)>

# %%
loans = [
        {"loan_id": "L13669", "customer_id": "C9761"},
        {"loan_id": "L14012", "customer_id": "C4624"},
        {"loan_id": "L13463", "customer_id": "C8478"}
    ]

# %%
entity_row = [{"loan_id": "L13669", "customer_id": "C9761"}]

# %%
online_features = store.get_online_features(
    entity_rows=entity_row,
    features=feature_refs
).to_dict()

# %%
online_features
# Out:
# {'loan_id': ['L13669'],
#  'customer_id': ['C9761'],
#  'credit_score': [789],
#  'employment_years': [4.300000190734863],
#  'interest_rate': [17.600000381469727],
#  'urban_rural': ['Rural'],
#  'loan_term': [60],
#  'dti_ratio': [0.23000000417232513],
#  'province': ['South Sulawesi'],
#  'collateral_value': [101765152.0],
#  'product_type': ['Car'],
#  'loan_amount': [92929112.0],
#  'age': [41],
#  'monthly_income': [10546224.0],
#  'ltv_ratio': [0.9100000262260437]}

# %% [markdown]
# materialize failed with remote
#
# get online features failed with remote
#
# Push failed
